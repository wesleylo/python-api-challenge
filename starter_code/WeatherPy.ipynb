# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Use citipy to find city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

# Create a set of random lat lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# api url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


# List of city data
city_data = []

record = 0

# build city search query
for city in cities:
    city_url = url + "&q=" + city

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        record += 1 # Increment after successful entry
        
        print(f'Processing record #{record} of {len(cities)} | {city}' )
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing record #1 of 613 | luderitz
# City not found. Skipping...
# Processing record #2 of 613 | liku
# Processing record #3 of 613 | hermanus
# Processing record #4 of 613 | vaini
# Processing record #5 of 613 | provideniya
# Processing record #6 of 613 | kaitangata
# Processing record #7 of 613 | chuy
# Processing record #8 of 613 | butaritari
# Processing record #9 of 613 | netivot
# Processing record #10 of 613 | nome
# Processing record #11 of 613 | faanui
# Processing record #12 of 613 | itoman
# Processing record #13 of 613 | thompson
# Processing record #14 of 613 | murdochville
# Processing record #15 of 613 | padang
# Processing record #16 of 613 | kirgiz-miyaki
# Processing record #17 of 613 | koungou
# Processing record #18 of 613 | pacific grove
# Processing record #19 of 613 | taltal
# Processing record #20 of 613 | yulara
# Processing record #21 of 613 | viedma
# Processing record #22 of 613 | lima
# Processing record #23 of 613 | georgetown
# City not found. Skipping...
# Processing record #24 of 613 | jamestown
# Processing record #25 of 613 | barrow
# Processing record #26 of 613 | hithadhoo
# Processing record #27 of 613 | garissa
# Processing record #28 of 613 | port elizabeth
# Processing record #29 of 613 | ushuaia
# Processing record #30 of 613 | kandalaksha
# Processing record #31 of 613 | matara
# Processing record #32 of 613 | mataura
# Processing record #33 of 613 | souillac
# Processing record #34 of 613 | ponta do sol
# City not found. Skipping...
# Processing record #35 of 613 | hobart
# Processing record #36 of 613 | port alfred
# Processing record #37 of 613 | cape town
# Processing record #38 of 613 | saskylakh
# Processing record #39 of 613 | narrabri
# Processing record #40 of 613 | paso de los toros
# Processing record #41 of 613 | ancud
# Processing record #42 of 613 | comodoro rivadavia
# Processing record #43 of 613 | rikitea
# Processing record #44 of 613 | naze
# City not found. Skipping...
# Processing record #45 of 613 | bubaque
# Processing record #46 of 613 | icatu
# Processing record #47 of 613 | ilulissat
# Processing record #48 of 613 | coihaique
# Processing record #49 of 613 | hilo
# Processing record #50 of 613 | mehamn
# Processing record #51 of 613 | komsomolets
# Processing record #52 of 613 | lasa
# Processing record #53 of 613 | talcahuano
# Processing record #54 of 613 | mamallapuram
# Processing record #55 of 613 | east london
# Processing record #56 of 613 | albany
# Processing record #57 of 613 | wembley
# Processing record #58 of 613 | avera
# Processing record #59 of 613 | talnakh
# Processing record #60 of 613 | sao filipe
# Processing record #61 of 613 | mar del plata
# Processing record #62 of 613 | tiksi
# Processing record #63 of 613 | khatanga
# Processing record #64 of 613 | salalah
# City not found. Skipping...
# Processing record #65 of 613 | bambanglipuro
# Processing record #66 of 613 | saint-joseph
# City not found. Skipping...
# Processing record #67 of 613 | te anau
# Processing record #68 of 613 | ovsyanka
# Processing record #69 of 613 | chokurdakh
# Processing record #70 of 613 | guerrero negro
# Processing record #71 of 613 | bluff
# Processing record #72 of 613 | luau
# Processing record #73 of 613 | bredasdorp
# Processing record #74 of 613 | kruisfontein
# City not found. Skipping...
# Processing record #75 of 613 | saint anthony
# Processing record #76 of 613 | bambous virieux
# Processing record #77 of 613 | kommunar
# Processing record #78 of 613 | san patricio
# Processing record #79 of 613 | brindisi
# City not found. Skipping...
# Processing record #80 of 613 | indian head
# Processing record #81 of 613 | biltine
# Processing record #82 of 613 | udachnyy
# Processing record #83 of 613 | alice town
# Processing record #84 of 613 | bintulu
# Processing record #85 of 613 | fare
# City not found. Skipping...
# City not found. Skipping...
# Processing record #86 of 613 | broome
# Processing record #87 of 613 | katakwi
# Processing record #88 of 613 | husavik
# Processing record #89 of 613 | rumoi
# Processing record #90 of 613 | hun
# Processing record #91 of 613 | barra dos coqueiros
# Processing record #92 of 613 | klyuchi
# Processing record #93 of 613 | sola
# Processing record #94 of 613 | cidreira
# Processing record #95 of 613 | dinar
# Processing record #96 of 613 | grand forks
# Processing record #97 of 613 | torbay
# Processing record #98 of 613 | hay river
# Processing record #99 of 613 | tasiilaq
# Processing record #100 of 613 | pisco
# Processing record #101 of 613 | saint-philippe
# Processing record #102 of 613 | norman wells
# Processing record #103 of 613 | abha
# Processing record #104 of 613 | kajaani
# City not found. Skipping...
# Processing record #105 of 613 | sabang
# Processing record #106 of 613 | dikson
# Processing record #107 of 613 | ruteng
# Processing record #108 of 613 | katsuura
# Processing record #109 of 613 | ballina
# Processing record #110 of 613 | corowa
# Processing record #111 of 613 | bethel
# Processing record #112 of 613 | daru
# Processing record #113 of 613 | severo-kurilsk
# Processing record #114 of 613 | espanola
# Processing record #115 of 613 | port hardy
# Processing record #116 of 613 | avarua
# Processing record #117 of 613 | kapaa
# Processing record #118 of 613 | hami
# Processing record #119 of 613 | carnarvon
# Processing record #120 of 613 | abonnema
# Processing record #121 of 613 | canico
# Processing record #122 of 613 | punta arenas
# Processing record #123 of 613 | kailua
# Processing record #124 of 613 | north platte
# Processing record #125 of 613 | vangaindrano
# Processing record #126 of 613 | limulunga
# Processing record #127 of 613 | banjar
# Processing record #128 of 613 | boralday
# City not found. Skipping...
# Processing record #129 of 613 | atuona
# City not found. Skipping...
# Processing record #130 of 613 | ayna
# Processing record #131 of 613 | valley city
# City not found. Skipping...
# Processing record #132 of 613 | marquette
# Processing record #133 of 613 | upernavik
# Processing record #134 of 613 | lebu
# City not found. Skipping...
# City not found. Skipping...
# Processing record #135 of 613 | nikolskoye
# Processing record #136 of 613 | baoqing
# Processing record #137 of 613 | qaanaaq
# Processing record #138 of 613 | suntar
# Processing record #139 of 613 | rawson
# City not found. Skipping...
# Processing record #140 of 613 | castro
# Processing record #141 of 613 | tabou
# Processing record #142 of 613 | lahij
# Processing record #143 of 613 | half moon bay
# Processing record #144 of 613 | busselton
# Processing record #145 of 613 | bogale
# Processing record #146 of 613 | arraial do cabo
# Processing record #147 of 613 | lewistown
# Processing record #148 of 613 | sibu
# Processing record #149 of 613 | lubumbashi
# Processing record #150 of 613 | mozarlandia
# Processing record #151 of 613 | tadine
# Processing record #152 of 613 | oparino
# Processing record #153 of 613 | saint george
# Processing record #154 of 613 | mazatan
# Processing record #155 of 613 | kununurra
# Processing record #156 of 613 | montes altos
# Processing record #157 of 613 | ribeira grande
# Processing record #158 of 613 | lagoa
# Processing record #159 of 613 | cayenne
# Processing record #160 of 613 | mlonggo
# Processing record #161 of 613 | codrington
# Processing record #162 of 613 | mount isa
# Processing record #163 of 613 | anupgarh
# Processing record #164 of 613 | korla
# Processing record #165 of 613 | cherat
# Processing record #166 of 613 | san cristobal
# Processing record #167 of 613 | eganville
# Processing record #168 of 613 | saldanha
# Processing record #169 of 613 | roald
# Processing record #170 of 613 | egvekinot
# Processing record #171 of 613 | hope
# Processing record #172 of 613 | esperance
# Processing record #173 of 613 | sisimiut
# City not found. Skipping...
# Processing record #174 of 613 | mahibadhoo
# Processing record #175 of 613 | tuktoyaktuk
# Processing record #176 of 613 | ranong
# Processing record #177 of 613 | kavieng
# Processing record #178 of 613 | vostok
# Processing record #179 of 613 | muros
# Processing record #180 of 613 | kavaratti
# Processing record #181 of 613 | novo aripuana
# Processing record #182 of 613 | cockburn town
# Processing record #183 of 613 | maceio
# Processing record #184 of 613 | poya
# Processing record #185 of 613 | nanortalik
# Processing record #186 of 613 | sakakah
# Processing record #187 of 613 | ahipara
# Processing record #188 of 613 | beisfjord
# Processing record #189 of 613 | romny
# Processing record #190 of 613 | quatre cocos
# Processing record #191 of 613 | niteroi
# Processing record #192 of 613 | mirabad
# Processing record #193 of 613 | lovozero
# Processing record #194 of 613 | dunmore town
# Processing record #195 of 613 | aswan
# City not found. Skipping...
# Processing record #196 of 613 | mocuba
# City not found. Skipping...
# Processing record #197 of 613 | ejido
# Processing record #198 of 613 | ginir
# Processing record #199 of 613 | porbandar
# Processing record #200 of 613 | karagaylinskiy
# Processing record #201 of 613 | vardo
# City not found. Skipping...
# Processing record #202 of 613 | bridlington
# Processing record #203 of 613 | trelew
# Processing record #204 of 613 | rey bouba
# Processing record #205 of 613 | uitenhage
# Processing record #206 of 613 | sabha
# Processing record #207 of 613 | longyearbyen
# Processing record #208 of 613 | peto
# Processing record #209 of 613 | abu dhabi
# Processing record #210 of 613 | eirunepe
# Processing record #211 of 613 | bengkulu
# Processing record #212 of 613 | tomatlan
# Processing record #213 of 613 | el alto
# Processing record #214 of 613 | haapiti
# Processing record #215 of 613 | sitka
# Processing record #216 of 613 | pindiga
# Processing record #217 of 613 | port lincoln
# Processing record #218 of 613 | aklavik
# Processing record #219 of 613 | new norfolk
# Processing record #220 of 613 | teterow
# Processing record #221 of 613 | xilitla
# Processing record #222 of 613 | high level
# Processing record #223 of 613 | hokitika
# Processing record #224 of 613 | rio gallegos
# Processing record #225 of 613 | vila franca do campo
# Processing record #226 of 613 | the valley
# Processing record #227 of 613 | nemuro
# Processing record #228 of 613 | palmer
# Processing record #229 of 613 | wagga wagga
# Processing record #230 of 613 | palora
# Processing record #231 of 613 | clyde river
# Processing record #232 of 613 | mount gambier
# Processing record #233 of 613 | waiuku
# City not found. Skipping...
# Processing record #234 of 613 | fortuna
# Processing record #235 of 613 | anadyr
# City not found. Skipping...
# Processing record #236 of 613 | katherine
# Processing record #237 of 613 | palaikastron
# Processing record #238 of 613 | mahebourg
# Processing record #239 of 613 | praya
# Processing record #240 of 613 | conde
# Processing record #241 of 613 | victoria
# Processing record #242 of 613 | charters towers
# Processing record #243 of 613 | moranbah
# Processing record #244 of 613 | novoselitskoye
# Processing record #245 of 613 | asau
# Processing record #246 of 613 | hasaki
# Processing record #247 of 613 | lavrentiya
# Processing record #248 of 613 | springbok
# Processing record #249 of 613 | shubarkuduk
# Processing record #250 of 613 | puerto ayora
# Processing record #251 of 613 | vagur
# Processing record #252 of 613 | khasan
# Processing record #253 of 613 | quelimane
# Processing record #254 of 613 | ryotsu
# Processing record #255 of 613 | marsala
# Processing record #256 of 613 | batticaloa
# Processing record #257 of 613 | ampanihy
# Processing record #258 of 613 | baykit
# Processing record #259 of 613 | kumylzhenskaya
# Processing record #260 of 613 | yerbogachen
# Processing record #261 of 613 | hualmay
# Processing record #262 of 613 | waupun
# City not found. Skipping...
# Processing record #263 of 613 | caceres
# Processing record #264 of 613 | qasigiannguit
# Processing record #265 of 613 | mana
# Processing record #266 of 613 | karratha
# Processing record #267 of 613 | yar-sale
# Processing record #268 of 613 | salinopolis
# Processing record #269 of 613 | los llanos de aridane
# Processing record #270 of 613 | portland
# Processing record #271 of 613 | owando
# Processing record #272 of 613 | gusau
# Processing record #273 of 613 | dingle
# Processing record #274 of 613 | coahuayana
# Processing record #275 of 613 | channel-port aux basques
# Processing record #276 of 613 | khandyga
# Processing record #277 of 613 | cherskiy
# City not found. Skipping...
# Processing record #278 of 613 | herat
# Processing record #279 of 613 | sobolevo
# Processing record #280 of 613 | linjiang
# Processing record #281 of 613 | jacareacanga
# Processing record #282 of 613 | omboue
# Processing record #283 of 613 | mogadishu
# Processing record #284 of 613 | sevsk
# Processing record #285 of 613 | ziway
# Processing record #286 of 613 | caravelas
# Processing record #287 of 613 | baracoa
# Processing record #288 of 613 | chicama
# Processing record #289 of 613 | hovd
# Processing record #290 of 613 | richards bay
# Processing record #291 of 613 | casablanca
# Processing record #292 of 613 | sao jose da coroa grande
# Processing record #293 of 613 | mareeba
# Processing record #294 of 613 | geraldton
# Processing record #295 of 613 | anqing
# City not found. Skipping...
# Processing record #296 of 613 | cap-haitien
# Processing record #297 of 613 | sur
# Processing record #298 of 613 | nedjo
# City not found. Skipping...
# Processing record #299 of 613 | galesong
# Processing record #300 of 613 | camacha
# Processing record #301 of 613 | birjand
# Processing record #302 of 613 | pemba
# Processing record #303 of 613 | kodiak
# Processing record #304 of 613 | alofi
# Processing record #305 of 613 | hovin
# Processing record #306 of 613 | tinskoy
# Processing record #307 of 613 | nizwa
# Processing record #308 of 613 | novyy urengoy
# Processing record #309 of 613 | ulladulla
# Processing record #310 of 613 | yellowknife
# Processing record #311 of 613 | leningradskiy
# Processing record #312 of 613 | gaoual
# City not found. Skipping...
# City not found. Skipping...
# Processing record #313 of 613 | kitimat
# Processing record #314 of 613 | cap malheureux
# Processing record #315 of 613 | pulaski
# City not found. Skipping...
# Processing record #316 of 613 | flinders
# Processing record #317 of 613 | pangody
# Processing record #318 of 613 | port blair
# Processing record #319 of 613 | mackay
# Processing record #320 of 613 | samarai
# Processing record #321 of 613 | wilmington
# Processing record #322 of 613 | ust-kuyga
# Processing record #323 of 613 | kissidougou
# Processing record #324 of 613 | havoysund
# Processing record #325 of 613 | kumphawapi
# Processing record #326 of 613 | alice springs
# Processing record #327 of 613 | harindanga
# Processing record #328 of 613 | auki
# Processing record #329 of 613 | sorland
# Processing record #330 of 613 | mtsamboro
# Processing record #331 of 613 | sandpoint
# Processing record #332 of 613 | mayo
# Processing record #333 of 613 | cabo san lucas
# City not found. Skipping...
# Processing record #334 of 613 | lompoc
# Processing record #335 of 613 | belmonte
# Processing record #336 of 613 | malanje
# Processing record #337 of 613 | acari
# Processing record #338 of 613 | saint-pierre
# Processing record #339 of 613 | oia
# Processing record #340 of 613 | gillette
# Processing record #341 of 613 | cody
# Processing record #342 of 613 | mikhaylovka
# Processing record #343 of 613 | manga
# Processing record #344 of 613 | kaduqli
# Processing record #345 of 613 | dickinson
# Processing record #346 of 613 | yabelo
# Processing record #347 of 613 | megion
# Processing record #348 of 613 | san quintin
# Processing record #349 of 613 | basavakalyan
# City not found. Skipping...
# Processing record #350 of 613 | airai
# City not found. Skipping...
# Processing record #351 of 613 | zyryanka
# Processing record #352 of 613 | ogbomosho
# Processing record #353 of 613 | beringovskiy
# Processing record #354 of 613 | oranjemund
# Processing record #355 of 613 | ardakan
# Processing record #356 of 613 | inongo
# Processing record #357 of 613 | arlit
# Processing record #358 of 613 | hue
# Processing record #359 of 613 | valky
# Processing record #360 of 613 | dondaicha
# Processing record #361 of 613 | veraval
# Processing record #362 of 613 | chapais
# Processing record #363 of 613 | bloemfontein
# Processing record #364 of 613 | carauari
# City not found. Skipping...
# Processing record #365 of 613 | dimbokro
# Processing record #366 of 613 | bageshwar
# Processing record #367 of 613 | brigantine
# Processing record #368 of 613 | moree
# Processing record #369 of 613 | lorengau
# Processing record #370 of 613 | gornopravdinsk
# Processing record #371 of 613 | haines junction
# Processing record #372 of 613 | bandarbeyla
# Processing record #373 of 613 | bac lieu
# Processing record #374 of 613 | namibe
# Processing record #375 of 613 | fort nelson
# Processing record #376 of 613 | wanning
# Processing record #377 of 613 | hondo
# City not found. Skipping...
# Processing record #378 of 613 | wapakoneta
# Processing record #379 of 613 | ostrovnoy
# Processing record #380 of 613 | alvand
# Processing record #381 of 613 | urengoy
# Processing record #382 of 613 | iqaluit
# City not found. Skipping...
# Processing record #383 of 613 | hoquiam
# Processing record #384 of 613 | pevek
# Processing record #385 of 613 | kosh-agach
# Processing record #386 of 613 | martapura
# Processing record #387 of 613 | hofn
# City not found. Skipping...
# Processing record #388 of 613 | santa rosa de viterbo
# Processing record #389 of 613 | kalabo
# Processing record #390 of 613 | bathsheba
# Processing record #391 of 613 | qaqortoq
# Processing record #392 of 613 | lerwick
# Processing record #393 of 613 | saint-augustin
# Processing record #394 of 613 | sechura
# Processing record #395 of 613 | malakal
# Processing record #396 of 613 | alipur chatha
# Processing record #397 of 613 | balabac
# City not found. Skipping...
# City not found. Skipping...
# Processing record #398 of 613 | ust-tsilma
# Processing record #399 of 613 | ascension
# Processing record #400 of 613 | eureka
# Processing record #401 of 613 | bardiyah
# Processing record #402 of 613 | san ramon
# Processing record #403 of 613 | ararangua
# Processing record #404 of 613 | zhumadian
# Processing record #405 of 613 | houma
# Processing record #406 of 613 | santa maria
# Processing record #407 of 613 | vestmanna
# Processing record #408 of 613 | high prairie
# Processing record #409 of 613 | san andres
# Processing record #410 of 613 | nichinan
# Processing record #411 of 613 | makakilo city
# Processing record #412 of 613 | waipawa
# Processing record #413 of 613 | edson
# Processing record #414 of 613 | akureyri
# City not found. Skipping...
# Processing record #415 of 613 | kasane
# Processing record #416 of 613 | eyl
# Processing record #417 of 613 | christchurch
# Processing record #418 of 613 | kahului
# Processing record #419 of 613 | dauriya
# Processing record #420 of 613 | marion
# City not found. Skipping...
# Processing record #421 of 613 | kloulklubed
# Processing record #422 of 613 | nipawin
# City not found. Skipping...
# Processing record #423 of 613 | conselheiro pena
# Processing record #424 of 613 | westport
# Processing record #425 of 613 | jalu
# Processing record #426 of 613 | sangar
# Processing record #427 of 613 | riyadh
# Processing record #428 of 613 | adrian
# Processing record #429 of 613 | srednekolymsk
# Processing record #430 of 613 | cairns
# Processing record #431 of 613 | fairbanks
# Processing record #432 of 613 | amalapuram
# Processing record #433 of 613 | winnemucca
# Processing record #434 of 613 | blagoyevo
# Processing record #435 of 613 | silver city
# Processing record #436 of 613 | fiche
# Processing record #437 of 613 | tura
# Processing record #438 of 613 | dunedin
# Processing record #439 of 613 | havelock
# Processing record #440 of 613 | copiapo
# Processing record #441 of 613 | buraydah
# Processing record #442 of 613 | kure
# Processing record #443 of 613 | chimbote
# Processing record #444 of 613 | helena
# City not found. Skipping...
# Processing record #445 of 613 | camacari
# Processing record #446 of 613 | bonthe
# Processing record #447 of 613 | santa isabel do rio negro
# Processing record #448 of 613 | nha trang
# Processing record #449 of 613 | kodino
# Processing record #450 of 613 | quimper
# Processing record #451 of 613 | joshimath
# Processing record #452 of 613 | odweyne
# Processing record #453 of 613 | soyo
# Processing record #454 of 613 | nouadhibou
# Processing record #455 of 613 | vao
# Processing record #456 of 613 | lamovita
# Processing record #457 of 613 | eydhafushi
# Processing record #458 of 613 | zavyalovo
# Processing record #459 of 613 | emba
# Processing record #460 of 613 | enshi
# Processing record #461 of 613 | mineiros
# Processing record #462 of 613 | bonavista
# City not found. Skipping...
# City not found. Skipping...
# Processing record #463 of 613 | kamyshlov
# Processing record #464 of 613 | pemangkat
# Processing record #465 of 613 | leshukonskoye
# Processing record #466 of 613 | lazaro cardenas
# Processing record #467 of 613 | tahta
# Processing record #468 of 613 | camana
# Processing record #469 of 613 | laguna
# Processing record #470 of 613 | trairi
# Processing record #471 of 613 | consett
# Processing record #472 of 613 | kremenchuk
# City not found. Skipping...
# Processing record #473 of 613 | tezu
# Processing record #474 of 613 | zhigalovo
# Processing record #475 of 613 | louga
# Processing record #476 of 613 | manjeshwar
# Processing record #477 of 613 | swift current
# Processing record #478 of 613 | porangatu
# Processing record #479 of 613 | mitsamiouli
# Processing record #480 of 613 | mecca
# Processing record #481 of 613 | poum
# Processing record #482 of 613 | pangnirtung
# Processing record #483 of 613 | pascagoula
# Processing record #484 of 613 | uvelskiy
# Processing record #485 of 613 | khuzhir
# Processing record #486 of 613 | mindelo
# Processing record #487 of 613 | vila velha
# Processing record #488 of 613 | grindavik
# Processing record #489 of 613 | hamilton
# Processing record #490 of 613 | port macquarie
# Processing record #491 of 613 | kremenki
# Processing record #492 of 613 | tautira
# Processing record #493 of 613 | tuatapere
# Processing record #494 of 613 | marmora
# City not found. Skipping...
# Processing record #495 of 613 | constitucion
# Processing record #496 of 613 | shiraz
# Processing record #497 of 613 | socorro
# Processing record #498 of 613 | batemans bay
# Processing record #499 of 613 | inndyr
# City not found. Skipping...
# City not found. Skipping...
# Processing record #500 of 613 | bucerias
# Processing record #501 of 613 | arecibo
# Processing record #502 of 613 | isla vista
# Processing record #503 of 613 | kindu
# Processing record #504 of 613 | lydenburg
# Processing record #505 of 613 | hadejia
# Processing record #506 of 613 | canmore
# Processing record #507 of 613 | mucurapo
# Processing record #508 of 613 | lucapa
# Processing record #509 of 613 | evensk
# Processing record #510 of 613 | polovinnoye
# Processing record #511 of 613 | abapo
# Processing record #512 of 613 | roma
# Processing record #513 of 613 | kiruna
# Processing record #514 of 613 | itupiranga
# Processing record #515 of 613 | kutum
# Processing record #516 of 613 | sinnamary
# Processing record #517 of 613 | kampot
# Processing record #518 of 613 | port-gentil
# Processing record #519 of 613 | ende
# Processing record #520 of 613 | deniliquin
# Processing record #521 of 613 | billings
# Processing record #522 of 613 | halifax
# City not found. Skipping...
# Processing record #523 of 613 | atambua
# Processing record #524 of 613 | vestmannaeyjar
# Processing record #525 of 613 | fairview
# Processing record #526 of 613 | boa vista
# Processing record #527 of 613 | cravo norte
# Processing record #528 of 613 | saint stephen
# Processing record #529 of 613 | tagusao
# City not found. Skipping...
# Processing record #530 of 613 | moindou
# Processing record #531 of 613 | namatanai
# Processing record #532 of 613 | kulhudhuffushi
# Processing record #533 of 613 | mamakan
# Processing record #534 of 613 | ola
# Processing record #535 of 613 | sheffield
# Processing record #536 of 613 | ostersund
# Processing record #537 of 613 | carberry
# City not found. Skipping...
# Processing record #538 of 613 | general roca
# City not found. Skipping...
# Processing record #539 of 613 | antalaha
# Processing record #540 of 613 | kangaatsiaq
# City not found. Skipping...
# Processing record #541 of 613 | ganzhou
# Processing record #542 of 613 | tabuk
# Processing record #543 of 613 | camopi
# Processing record #544 of 613 | esmeraldas
# Processing record #545 of 613 | san vicente
# Processing record #546 of 613 | brae
# Processing record #547 of 613 | boende
# Processing record #548 of 613 | beyla
# Processing record #549 of 613 | shenjiamen
# Processing record #550 of 613 | mahon
# Processing record #551 of 613 | magadan
# Processing record #552 of 613 | khunti
# Processing record #553 of 613 | dalmau
# Processing record #554 of 613 | devils lake
# Processing record #555 of 613 | alta floresta
# Processing record #556 of 613 | taoudenni
# Processing record #557 of 613 | marystown
# Processing record #558 of 613 | fengzhen
# Processing record #559 of 613 | maniitsoq

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
len(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     luderitz -26.6481   15.1594     73.98        46           0       10.20
# 1         liku  -0.7275  119.8922     78.22        80          82        4.43
# 2     hermanus -34.4187   19.2345     78.01        43           0       10.45
# 3        vaini -21.2000 -175.2000     77.00        78          20       10.36
# 4  provideniya  64.3833 -173.3000    -10.68        85          47        2.68
#
#   Country        Date
# 0      NA  1613988724
# 1      ID  1613988724
# 2      ZA  1613988724
# 3      TO  1613988724
# 4      RU  1613988724

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humid_city_data = city_data_df[(city_data_df["Humidity"] > 100)].index # find incicies of city_data with humidity > 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_df.drop(humid_city_data, inplace=False)
clean_city_data.describe()
clean_city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     luderitz -26.6481   15.1594     73.98        46           0       10.20
# 1         liku  -0.7275  119.8922     78.22        80          82        4.43
# 2     hermanus -34.4187   19.2345     78.01        43           0       10.45
# 3        vaini -21.2000 -175.2000     77.00        78          20       10.36
# 4  provideniya  64.3833 -173.3000    -10.68        85          47        2.68
#
#   Country        Date
# 0      NA  1613988724
# 1      ID  1613988724
# 2      ZA  1613988724
# 3      TO  1613988724
# 4      RU  1613988724

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot
plt.scatter(clean_city_data["Lat"], 
            clean_city_data["Max Temp"],
            edgecolor="black", marker="o")

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Save
plt.savefig("output_data/lat-temp-plot.png")

# Show plot
plt.show()

# %% [markdown]
# Analysis: Cities closer to the equator (latitude 0) have higher max temperatures.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build Latitude and Humidity scatterplot
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolor="black")

# add title and labels
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# save
plt.savefig("output_data/latitude-humidity.png")
plt.show()

# %% [markdown]
# Analysis: There is weak correlation between a city's latitude and humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build Latitude and Humidity scatterplot
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolor="black")

# add title and labels
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# save
plt.savefig("output_data/latitude-cloudiness.png")
plt.show()

# %% [markdown]
# Analysis: There is no significant relationship between city latitude and city cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build Latitude and Humidity scatterplot
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolor="black")

# add title and labels
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

# save
plt.savefig("output_data/latitude-windspeed.png")
plt.show()

# %% [markdown]
# Analysis: The data is fairly normal, meaning that there is no significant relationship between city latitude and city wind speed.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
